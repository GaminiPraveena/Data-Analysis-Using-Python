# %%
"""import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample car crash data
data = {
    'Speed': [50, 60, 70, 55, 45, 65, 75, 40, 55, 60],
    'Impact Force': [1000, 1200, 1500, 1100, 900, 1300, 1600, 800, 1000, 1200],
    'Severity': ['Minor', 'Major', 'Major', 'Minor', 'Minor', 'Major', 'Major', 'Minor', 'Minor', 'Major']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Scatter plot of speed vs. impact force
sns.scatterplot(data=df,x='Speed', y='Impact Force', hue='Severity')
plt.title('Car Crash Analysis')
plt.xlabel('Speed (mph)')
plt.ylabel('Impact Force (N)')
plt.show()"""
import seaborn as sns
cc=sns.load_dataset("car_crashes")
cc.head()
sns.catplot(data=cc,x='alcohol',y='ins_losses',kind="violin")

# %%
"""import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample exercise data
data = {
    'Exercise': ['Running', 'Cycling', 'Swimming', 'Weightlifting', 'Yoga'],
    'Duration (minutes)': [40, 50, 45, 60, 30]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the style
sns.set_style("whitegrid")

# Create a histogram of workout durations for each exercise
sns.histplot(data=df, x='Duration (minutes)', hue='Exercise', multiple="stack", bins=10)
plt.title('Distribution of Workout Durations by Exercise')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.legend(title='Exercise')
plt.show()"""
ex=sns.load_dataset("exercise")
ex.head()
sns.relplot(data=ex,x='pulse',y='time')

# %%
"""import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset (for example, using seaborn's built-in dataset)
mpg_data = sns.load_dataset('mpg')

# Set the style
sns.set_style("whitegrid")

# Create a histogram of mpg values
sns.histplot(data=mpg_data, x='mpg', bins=20)
plt.title('Distribution of Miles Per Gallon (mpg)')
plt.xlabel('Miles Per Gallon (mpg)')
plt.ylabel('Frequency')
plt.show()"""

mpg=sns.load_dataset("mpg")
mpg.head()
sns.relplot(data=mpg,x='horsepower',y='displacement',kind='line')
